# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("rakeshrau/social-network-ads")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /home/akyrr/.cache/kagglehub/datasets/rakeshrau/social-network-ads/versions/1
