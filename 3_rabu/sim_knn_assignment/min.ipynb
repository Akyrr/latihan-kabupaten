# %% [markdown]
# # **K - Nearest Neighbours**

# %% [markdown]
# ## 1. Data Understanding & Exploratory Data Analysis

# %% [markdown]
# ### 1.1 Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 1.2 Import & Understanding Data

# %%
# Import Assignment-2_Data.csv
assignment = pd.read_csv('Assignment-2_Data.csv')

# %%
# Tampilkan 5 baris teratas
print('\n5 baris teratas:')
assignment.head()
# Out:
# 5 baris teratas:
#      Id    age           job  marital  education default  balance housing  \
# 0  1001  999.0    management  married   tertiary      no   2143.0     yes
# 1  1002   44.0    technician   single  secondary      no     29.0     yes
# 2  1003   33.0  entrepreneur  married  secondary      no      2.0     yes
# 3  1004   47.0   blue-collar  married    unknown      no   1506.0     yes
# 4  1005   33.0       unknown   single    unknown      no      1.0      no
#
#   loan  contact  day month  duration  campaign  pdays  previous poutcome   y
# 0   no  unknown    5   may       261         1     -1         0  unknown  no
# 1   no  unknown    5   may       151         1     -1         0  unknown  no
# 2  yes  unknown    5   may        76         1     -1         0  unknown  no
# 3   no  unknown    5   may        92         1     -1         0  unknown  no
# 4   no  unknown    5   may       198         1     -1         0  unknown  no

# %%
# Tampilkan informasi dataste
print('\nInformasi dataset:')
assignment.info()
# Out:
# Informasi dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 18 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Id         45211 non-null  int64
#  1   age        45202 non-null  float64
#  2   job        45211 non-null  object
#  3   marital    45211 non-null  object
#  4   education  45211 non-null  object
#  5   default    45211 non-null  object
#  6   balance    45208 non-null  float64
#  7   housing    45211 non-null  object
#  8   loan       45211 non-null  object
#  9   contact    45211 non-null  object
#  10  day        45211 non-null  int64
#  11  month      45211 non-null  object
#  12  duration   45211 non-null  int64
#  13  campaign   45211 non-null  int64
#  14  pdays      45211 non-null  int64
#  15  previous   45211 non-null  int64
#  16  poutcome   45211 non-null  object
#  17  y          45211 non-null  object
# dtypes: float64(2), int64(6), object(10)
# memory usage: 6.2+ MB

# %%
# Tampilkan jumlah sample dan fitur dataset
print('\nJumlah sampel dan fitur dataset:')
print('Jumlah baris:', assignment.shape[0])
print('Jumlah kolom:', assignment.shape[1])
# Out:
# Jumlah sampel dan fitur dataset:
# Jumlah baris: 45211
# Jumlah kolom: 18

# %%
# Tampilkan nilai unik per fitur
print('\nNilai unik per fitur:')
for col in assignment.columns:
    print(f'=== Nilai Unik Fitur {col} ===')
    print('Jumlah nilai unik:', assignment[col].nunique())
    print(f'Nilai unik fitur {col}:', assignment[col].unique())
    print('-' * 30) # Garis pembatas agar lebih rapi
# Out:
# Nilai unik per fitur:
# === Nilai Unik Fitur Id ===
# Jumlah nilai unik: 45211
# Nilai unik fitur Id: [ 1001  1002  1003 ... 46209 46210 46211]
# ------------------------------
# === Nilai Unik Fitur age ===
# Jumlah nilai unik: 79
# Nilai unik fitur age: [999.  44.  33.  47.  35.  28.  nan  58.  43.  41.  29.  53.  57.  51.
#   45.  60.  56.  32.  25.  40.  39.  52.  46.  36.  49.  59.  37.  50.
#   54.  55.  48.  31.  42.  30.  27.  34.  38.  23.  26.  61.  22.  24.
#   21.  20.  66.  62.  83.  75.  67.  70.  65.  68.  64.  69.  72.  71.
#   19.  76.  85.  63.  90.  82.  73.  74.  78.  80.  94.  79.  77.  86.
#   95.  81.  18.  89.  84.  87.  92.  93.  88.  -1.]
# ------------------------------
# === Nilai Unik Fitur job ===
# Jumlah nilai unik: 12
# Nilai unik fitur job: ['management' 'technician' 'entrepreneur' 'blue-collar' 'unknown'
#  'retired' 'admin.' 'services' 'self-employed' 'unemployed' 'housemaid'
#  'student']
# ------------------------------
# === Nilai Unik Fitur marital ===
# Jumlah nilai unik: 3
# Nilai unik fitur marital: ['married' 'single' 'divorced']
# ------------------------------
# === Nilai Unik Fitur education ===
# Jumlah nilai unik: 4
# Nilai unik fitur education: ['tertiary' 'secondary' 'unknown' 'primary']
# ------------------------------
# === Nilai Unik Fitur default ===
# Jumlah nilai unik: 2
# Nilai unik fitur default: ['no' 'yes']
# ------------------------------
# === Nilai Unik Fitur balance ===
# Jumlah nilai unik: 7168
# Nilai unik fitur balance: [2.1430e+03 2.9000e+01 2.0000e+00 ... 8.2050e+03 1.4204e+04 1.6353e+04]
# ------------------------------
# === Nilai Unik Fitur housing ===
# Jumlah nilai unik: 2
# Nilai unik fitur housing: ['yes' 'no']
# ------------------------------
# === Nilai Unik Fitur loan ===
# Jumlah nilai unik: 2
# Nilai unik fitur loan: ['no' 'yes']
# ------------------------------
# === Nilai Unik Fitur contact ===
# Jumlah nilai unik: 3
# Nilai unik fitur contact: ['unknown' 'cellular' 'telephone']
# ------------------------------
# === Nilai Unik Fitur day ===
# Jumlah nilai unik: 31
# Nilai unik fitur day: [ 5  6  7  8  9 12 13 14 15 16 19 20 21 23 26 27 28 29 30  2  3  4 11 17
#  18 24 25  1 10 22 31]
# ------------------------------
# === Nilai Unik Fitur month ===
# Jumlah nilai unik: 12
# Nilai unik fitur month: ['may' 'jun' 'jul' 'aug' 'oct' 'nov' 'dec' 'jan' 'feb' 'mar' 'apr' 'sep']
# ------------------------------
# === Nilai Unik Fitur duration ===
# Jumlah nilai unik: 1573
# Nilai unik fitur duration: [ 261  151   76 ... 1298 1246 1556]
# ------------------------------
# === Nilai Unik Fitur campaign ===
# Jumlah nilai unik: 48
# Nilai unik fitur campaign: [ 1  2  3  5  4  6  7  8  9 10 11 12 13 19 14 24 16 32 18 22 15 17 25 21
#  43 51 63 41 26 28 55 50 38 23 20 29 31 37 30 46 27 58 33 35 34 36 39 44]
# ------------------------------
# === Nilai Unik Fitur pdays ===
# Jumlah nilai unik: 559
# Nilai unik fitur pdays: [ -1 151 166  91  86 143 147  89 140 176 101 174 170 167 195 165 129 188
#  196 172 118 119 104 171 117 164 132 131 123 159 186 111 115 116 173 178
#  110 152  96 103 150 175 193 181 185 154 145 138 126 180 109 158 168  97
#  182 127 130 194 125 105 102  26 179  28 183 155 112 120 137 124 187 190
#  113 162 134 169 189   8 144 191 184 177   5  99 133  93  92  10 100 156
#  198 106 153 146 128   7 121 160 107  90  27 197 136 139 122 157 149 135
#   30 114  98 192 163  34  95 141  31 199  94 108  29 268 247 253 226 244
#  239 245 204 231 238 258 230 254 265  71 223 246 250 266 240 205 261 259
#  241 260 234 251 225 161 237 262 248 255 220 227 206 224 249 235 228 263
#    2 270 232 252 207 200 269 233 256 273 272 242 264 208 214 222 271 203
#  221 202 216 201 257 229 210 217  75 213  73  76 267 211 215  77 236  82
#    6 209 274   1 243 212 275  80 276   9 279  12 280  88 277  85  84 219
#   24  21 282  41 294  49 329 307 303 331 308 300  64 314 287 330 332 302
#  323 318 333  60 326 335 313 312 305 325 327 336 309 328 322  39 316 292
#  295 310 306 320 317 289  57 321 142 339 301 315 337 334 340 319  17  74
#  148 341 299 344 342 324 345 346 304 281 343 338  14 347  15 291 348 349
#  285 350 284  25 283 278  81   4  87  83  79  70  13 293  37  78  63  22
#  296 355  66  19  35 360 357 354 351 362 358 365 298 286 364 363  47 361
#  288 366 356 352 359 297 367 353 368  42 290  67 371 370 369  50  36 373
#  374 372 311 375 378  59 379  40  18  43  20  69  38 385  56  55  44 391
#   72 390  32  62 399 393  65 377 395 388 389 386  61 412 405 434 394 382
#  459 440 397 383  68 461 462 463 422  51 457 430 442 403 454 428 392 410
#  401 474 475 477 478  54 476 380 479  45  46 495  58  48 518  52 515 520
#  511 536 387 218  33 544 435 436 555 433 446 558 469 616 561 553 384 592
#  467 585 480 421 667 626 426 595 381 376 648 521 452 449 633 398  53 460
#  670 551 414 557 687 404 651 686 425 504 578 674 416 586 411 756 450 745
#  514 417 424 776 396 683 529 439 415 456 407 458 532 481 791 701 531 792
#  413 445 535 784 419 455 491 431 542 470 472 717 437   3 782 728 828 524
#  562 761 492 775 579 493 464 760 466 465 656 831 490 432 655 427 749 838
#  769 587 778 854 779 850 771 594 842 589 603 484 489 486 409 444 680 808
#  485 503 690 772 774 526 420 528 500 826 804 508 547 805 541 543 871 550
#  530]
# ------------------------------
# === Nilai Unik Fitur previous ===
# Jumlah nilai unik: 41
# Nilai unik fitur previous: [  0   3   1   4   2  11  16   6   5  10  12   7  18   9  21   8  14  15
#   26  37  13  25  20  27  17  23  38  29  24  51 275  22  19  30  58  28
#   32  40  55  35  41]
# ------------------------------
# === Nilai Unik Fitur poutcome ===
# Jumlah nilai unik: 4
# Nilai unik fitur poutcome: ['unknown' 'failure' 'other' 'success']
# ------------------------------
# === Nilai Unik Fitur y ===
# Jumlah nilai unik: 2
# Nilai unik fitur y: ['no' 'yes']
# ------------------------------

# %%
# Fungsi cek nilai unik per fitur
def unique_values(feature_name):
    print(f'=== Nilai Unik Fitur {feature_name} ===')
    print('Jumlah nilai unik:', assignment[feature_name].nunique())
    print('Nilai unik:', assignment[feature_name].unique())

# %%
# Pembagian tipe data fitur 
num_cols = assignment.select_dtypes(include=['int64', 'float64']).columns
cat_cols = assignment.select_dtypes(include=['object', 'category']).columns

print('Fitur numerik:', num_cols, '\n')
print('Fitur kategori:', cat_cols)
# Out:
# Fitur numerik: Index(['Id', 'age', 'balance', 'day', 'duration', 'campaign', 'pdays',
#        'previous'],
#       dtype='object')
#
# Fitur kategori: Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'poutcome', 'y'],
#       dtype='object')

# %%
# Panggil fungsi unique_values 
unique_values('Id')
# Out:
# === Nilai Unik Fitur Id ===
# Jumlah nilai unik: 45211
# Nilai unik: [ 1001  1002  1003 ... 46209 46210 46211]

# %% [markdown]
# ### 1.3 Missing Value dan Data Duplikat

# %% [markdown]
# #### 1.3.1 Missing Value

# %%
# Tampilkan total missing value
print('Total missing value:', assignment.isnull().sum().sum())
# Out:
# Total missing value: 12

# %%
# Tampilkan total missing value per fitur
print('\nJumlah missing value per fitur:')
assignment.isnull().sum()
# Out:
# Jumlah missing value per fitur:
# Id           0
# age          9
# job          0
# marital      0
# education    0
# default      0
# balance      3
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
# Tampilkan baris yang memiliki missing value 
assignment[assignment.isnull().any(axis=1)]
# Out:
#       Id   age           job   marital  education default  balance housing  \
# 7   1008   NaN  entrepreneur  divorced   tertiary     yes      NaN     yes
# 8   1009  58.0       retired   married    primary      no      NaN     yes
# 9   1010  43.0    technician    single  secondary      no      NaN     yes
# 53  1054   NaN        admin.    single  secondary      no    -76.0     yes
# 54  1055   NaN    technician    single  secondary      no   -103.0     yes
# 55  1056   NaN  entrepreneur    single   tertiary      no    243.0      no
# 56  1057   NaN    management    single   tertiary      no    424.0     yes
# 57  1058   NaN   blue-collar   married    unknown      no    306.0     yes
# 58  1059   NaN   blue-collar    single    unknown      no     24.0     yes
# 59  1060   NaN      services   married    primary      no    179.0     yes
# 60  1061   NaN        admin.   married   tertiary      no      0.0     yes
#
#    loan  contact  day month  duration  campaign  pdays  previous poutcome   y
# 7    no  unknown    5   may       380         1     -1         0  unknown  no
# 8    no  unknown    5   may        50         1     -1         0  unknown  no
# 9    no  unknown    5   may        55         1     -1         0  unknown  no
# 53   no  unknown    5   may       787         1     -1         0  unknown  no
# 54  yes  unknown    5   may       145         1     -1         0  unknown  no
# 55  yes  unknown    5   may       174         1     -1         0  unknown  no
# 56   no  unknown    5   may       104         1     -1         0  unknown  no
# 57   no  unknown    5   may        13         1     -1         0  unknown  no
# 58   no  unknown    5   may       185         1     -1         0  unknown  no
# 59   no  unknown    5   may      1778         1     -1         0  unknown  no
# 60   no  unknown    5   may       138         1     -1         0  unknown  no

# %% [markdown]
# #### 1.3.2 Data Duplikat

# %%
# Tampilkan total data duplikat 
print('Total data duplikat:', assignment.duplicated().sum())
# Out:
# Total data duplikat: 0

# %% [markdown]
# ### 1.4 Exploratory Data Analysis

# %% [markdown]
# #### 1.4.1 Statistik Dataset

# %%
# Tampilkan statistik dataset fitur numerik
assignment.describe()
# Out:
#                  Id           age        balance           day      duration  \
# count  45211.000000  45202.000000   45208.000000  45211.000000  45211.000000
# mean   23606.000000     40.954714    1362.346620     15.806419    258.163080
# std    13051.435847     11.539144    3044.852387      8.322476    257.527812
# min     1001.000000     -1.000000   -8019.000000      1.000000      0.000000
# 25%    12303.500000     33.000000      72.000000      8.000000    103.000000
# 50%    23606.000000     39.000000     448.000000     16.000000    180.000000
# 75%    34908.500000     48.000000    1428.000000     21.000000    319.000000
# max    46211.000000    999.000000  102127.000000     31.000000   4918.000000
#
#            campaign         pdays      previous
# count  45211.000000  45211.000000  45211.000000
# mean       2.763841     40.197828      0.580323
# std        3.098021    100.128746      2.303441
# min        1.000000     -1.000000      0.000000
# 25%        1.000000     -1.000000      0.000000
# 50%        2.000000     -1.000000      0.000000
# 75%        3.000000     -1.000000      0.000000
# max       63.000000    871.000000    275.000000

# %% [markdown]
# Pada fitur numerik, cenderung memiliki standar deviation yang besar. Dengan selisih nilai minimum dan maksimum lumayan jauh. Sehingga, ada kemungkinan terdeteksi outlier.

# %% [markdown]
# #### 1.4.2 Penyebaran Dataset

# %%
# # Grafik scateerplot antar fitur
# sns.pairplot(assignment)
# plt.show()

# %% [markdown]
# Dari scatterplot diatas, setelah dianalisis, tidak ada pembagian kelompok yang jelas antar fitur.

# %%
# Histogram fitur target
plt.figure(figsize=(8,6))
plt.title('Distribusi Target dengan Histogram')
sns.histplot(data=assignment, x='y', hue='y', bins=2)
plt.show()

# %% [markdown]
# Penyebaran target tidak seimbang. Dimana target 'no' mendominasi dengan range 0 - 40000. Sedangkan, target 'yes' hanya memiliki range 0 - 5000.

# %%
print(cat_cols)
print(num_cols)
# Out:
# Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'poutcome', 'y'],
#       dtype='object')
# Index(['Id', 'age', 'balance', 'day', 'duration', 'campaign', 'pdays',
#        'previous'],
#       dtype='object')

# %%
# Penyebaran data numerik
for col in num_cols:
    plt.figure(figsize=(8,6))
    sns.histplot(x=assignment[col])
    plt.title(f'Penyebaran data fitur {col}')
    plt.show()

# %%
# penyebaran data kategori
for col in cat_cols:
    plt.figure(figsize=(8,6))
    plt.xticks(rotation=45)
    sns.histplot(x=assignment[col], hue=assignment[col])
    plt.title(f'Penyebaran data fitur {col}')
    plt.show()

# %% [markdown]
# #### 1.4.3 Outlier pada Fitur

# %%
# Tampilkan outlier per fitur
for col in num_cols:
    plt.figure(figsize=(8,6))
    sns.boxplot(x=assignment[col])
    plt.title(f'Grafik Boxplot Fitur {col}')
    plt.show()

# %% [markdown]
# #### 1.4.4 Korelasi antar Fitur

# %%
correlation = assignment.select_dtypes(include=np.number).corr()
correlation
# Out:
#                 Id       age   balance       day  duration  campaign  \
# Id        1.000000  0.010182  0.073605 -0.061465  0.013031 -0.102884
# age       0.010182  1.000000  0.090419 -0.010820 -0.004389  0.003452
# balance   0.073605  0.090419  1.000000  0.004471  0.021554 -0.014592
# day      -0.061465 -0.010820  0.004471  1.000000 -0.030206  0.162490
# duration  0.013031 -0.004389  0.021554 -0.030206  1.000000 -0.084570
# campaign -0.102884  0.003452 -0.014592  0.162490 -0.084570  1.000000
# pdays     0.437729 -0.022584  0.003425 -0.093044 -0.001565 -0.088628
# previous  0.271098  0.000289  0.016668 -0.051710  0.001203 -0.032855
#
#              pdays  previous
# Id        0.437729  0.271098
# age      -0.022584  0.000289
# balance   0.003425  0.016668
# day      -0.093044 -0.051710
# duration -0.001565  0.001203
# campaign -0.088628 -0.032855
# pdays     1.000000  0.454820
# previous  0.454820  1.000000

# %%
# Grafik heatmap
plt.figure(figsize=(8,6))
sns.heatmap(correlation, annot=True, cmap='coolwarm')
plt.title('Korelasi antar Fitur Numerik')
plt.show()

# %% [markdown]
# ### 1.5 Data Cleaning

# %% [markdown]
# #### 1.5.1 Menangani Missing Value

# %%
assignment = assignment.dropna()

# %%
print('Total missing value setelah ditangani', assignment.isnull().sum().sum())
# Out:
# Total missing value setelah ditangani 0

# %% [markdown]
# #### 1.5.2 Encoding Fitur Objek

# %%
# Encoding fitur 'job'
assignment['job'] = assignment['job'].map({
    'management': 0,
    'technician': 1,
    'entrepreneur': 2,
    'blue-collar':3,
    'unknown': 4,
    'admin': 5,
    'services': 6,
    'retired': 7,
    'self-employed': 8,
    'unemployed': 9,
    'housemaid': 10,
    'student': 11
})

# %%
# Encoding fitur 'marital'
assignment['marital'] = assignment['marital'].map({
    'married': 0,
    'single': 1,
    'divorced': 2,
})

# %%
# encoding fitur 'education'
assignment['education'] = assignment['education'].map({
    'tertiary': 0,
    'secondary': 1,
    'unknown': 2,
    'primary': 3,
})

# %%
# encoding fitur 'defult'
assignment['default'] = assignment['default'].map({
    'no': 0,
    'yes':1
})

# %%
# encoding fitur 'housing'
assignment['housing'] = assignment['housing'].map({
    'no': 0,
    'yes': 1
})

# %%
# encoding fitur 'loan'
assignment['loan'] = assignment['loan'].map({
    'no': 0,
    'yes': 1
})

# %%
assignment['contact'] = assignment['contact'].map({
    'unknown': 0,
    'cellular': 1,
    'telephone':2
    })

# %%
# Encoding fitur 'month'
assignment['month'] = assignment['month'].map({
    'jan': 0,
    'feb': 1,
    'mar': 2,
    'apr':3,
    'may': 4,
    'jun': 5,
    'jul': 6,
    'agu': 7,
    'sep': 8,
    'oct': 9,
    'nov': 10,
    'dec': 11
})

# %%
# encoding fitur 'poutcome'
assignment['poutcome'] = assignment['poutcome'].map({
    'unknown': 0,
    'failure': 1,
    'other': 2,
    'success': 3,
})

# %%
# encoding gitur'y'
assignment['y'] = assignment['y'].map({
    'no': 0,
    'yes': 1
})

# %%
assignment.head()
# Out:
#      Id    age  job  marital  education  default  balance  housing  loan  \
# 0  1001  999.0  0.0        0          0        0   2143.0        1     0
# 1  1002   44.0  1.0        1          1        0     29.0        1     0
# 2  1003   33.0  2.0        0          1        0      2.0        1     1
# 3  1004   47.0  3.0        0          2        0   1506.0        1     0
# 4  1005   33.0  4.0        1          2        0      1.0        0     0
#
#    contact  day  month  duration  campaign  pdays  previous  poutcome  y
# 0        0    5    4.0       261         1     -1         0         0  0
# 1        0    5    4.0       151         1     -1         0         0  0
# 2        0    5    4.0        76         1     -1         0         0  0
# 3        0    5    4.0        92         1     -1         0         0  0
# 4        0    5    4.0       198         1     -1         0         0  0

# %% [markdown]
# ## **MODEL**

# %%
X_before = assignment.drop(['Id', 'age'], axis=1)
y = assignment['y']

# %%
# normalisasi (X - X.min) / (X.max - X.min)
X = (X_before - X_before.min()) / (X_before.max() - X_before.min())

# standarisasi (X - X.mean) / X - X.std
# X =(X_before - X_before.mean()) / X_before - X_before.std()

# %%
np.random.seed(42)

idx_0 = np.where(y == 0)[0]
idx_1 = np.where(y == 1)[0]

np.random.shuffle(idx_0)
np.random.shuffle(idx_1)

train_0 = int(len(idx_0) * 0.8)
train_1 = int(len(idx_1) * 0.8)

train_idx = np.concatenate([idx_0[:train_0], idx_1[:train_1]])
test_idx = np.concatenate([idx_0[train_0:], idx_1[train_1:]])

np.random.shuffle(train_idx)
np.random.shuffle(test_idx)

X_train = X.iloc[train_idx].values
y_train = y.iloc[train_idx].values
X_test = X.iloc[test_idx].values
y_test = y.iloc[test_idx].values

# %%
def knn(X_train, y_train, X_test, k=3, p=2, weight='uniform'):
    # X_test is a single sample, 1D
    distances = np.sum(np.abs(X_train - X_test)**p, axis=1)**(1/p)
    
    sort = np.argsort(distances)
    nearest = sort[:k]
    nearest_label = y_train[nearest]
    nearest_distance = distances[nearest]
    
    if weight == 'uniform':
        votes = np.bincount(nearest_label)
    elif weight == 'weighted':
        weights = 1 / (nearest_distance + 1e-5)
        votes = np.zeros(np.max(y_train) + 1)
        for i in range(len(nearest_label)):
            votes[nearest_label[i]] += weights[i]
    
    return votes

# %%
# mencari weight terbaik

vote_method =['uniform', 'weighted']
best_weight = {}

for method in vote_method:
    correct = 0
    for i in range(len(X_test)):
        pred = knn(X_train, y_train, X_test[i], k=5, p=2, weight=method)
        predicted_label = np.argmax(pred)
        if predicted_label == y_test[i]:
            correct += 1
    acc = correct / len(X_test)
    best_weight[method] = acc
    print(f'method {method}, acc: {acc:.4f}')
# Out:
# method uniform, acc: 0.9716
# method weighted, acc: 0.9716

# %%
# Tampilkan data duplikat
print()

# %%
# # Grafik Pie
# plt.figure(figsize=(8,6))
# plt.title('Presentase Penyebaran Target')
# plt.pie(df['jenis_kelamin'].value_counts(), labels=df['jenis_kelamin'].value_counts().index, autopct='%1.1f%%')
# plt.legend(['Perempuan','Laki-Laki'])

# %%
# # Histogram
# plt.figure(figsize=(8,6))
# plt.title('Distribusi Target dengan Histogram')
# sns.histplot(data=df, x='jenis_kelamin', hue='jenis_kelamin', bins=2)
# plt.xticks([0,1], ['Laki-Laki', 'Perempuan'])
# plt.legend(labels=['Laki-Laki', 'Perempuan'])
# plt.show()

# %%
# survived = df[df['Survived'] == 1]['Age']
# not_survived = df[df['Survived'] == 0]['Age']
# plt.hist(not_survived,bins=20,alpha=0.6,edgecolor='black',color='red')
# plt.hist(survived,bins=20,alpha=0.6,edgecolor='black',color='green')
# plt.title('Distribusi Umur vs Survived')
# plt.xlabel('Age')
# plt.ylabel('Frequency')
# plt.legend(['Tidak Selamat', 'Selamat'])
# plt.show()

# %%
# columns = df.select_dtypes(include=['int64', 'float64']).columns
# columns = columns.drop('diagnosis')

# # Perulangan untuk cek outlier masing - masing kolom
# for col in columns:

#     # Menentukan kuartil atas dan bawah
#     Q1 = df[col].quantile(0.25)
#     Q3 = df[col].quantile(0.75)
     
#     # Menghitung interquartil
#     IQR = Q3 - Q1 

#     # Menentukan batas atas dan bawah
#     batas_bawah = Q1 - 1.5 * IQR
#     batas_atas = Q3 + 1.5 * IQR
    
#     # Menghitung jumlah outlier
#     outlier = (df[col] < batas_bawah) | (df[col] > batas_atas)
#     outlier_count = outlier.sum()

#     print(f"Kolom = {col}") 
#     print(f'Jumlah outlier = {outlier_count}\n')

#     # Mengubah outlier menjadi median
#     median_fix = df[col].median()

#     df.loc[outlier, col] = median_fix

# %%
# # Korelasi dengan heatmap

# plt.figure(figsize=(18,16))
# plt.title('Korelasi antar Fitur')
# sns.heatmap(corr_spearman, annot=True, cmap='coolwarm', fmt='.1f')

# %%
# # 10 negara dengan income tertinggi
# top_10_income = df.nlargest(10, 'income')


# plt.figure(figsize=(9, 5))
# sns.set_style('whitegrid')

# sns.barplot(
#     data=top_10_income, 
#     x='income', 
#     y='country', 
#     color='steelblue'
# )

# plt.title('10 Negara dengan Pendapatan Tertinggi', fontsize=14)
# plt.xlabel('Pendapatan (Income)')
# plt.ylabel('Negara')

# plt.tight_layout()
# plt.show()

# %%
# # Boxplot

# for col in num_cols:
#     plt.figure(figsize=(8,6))
#     sns.boxplot(x=df[col])
#     plt.show()

# %%
# # Visualisasi dua kolom kategorikal (Hubungan)
# sns.countplot(data=animals, x='Animal', hue='PawSize')
# plt.title('Penyebaran nilai fitur Animal vs Pawsize')
# plt.show()

# %%
# obj_cols = animals.select_dtypes(include=['object']).columns

# for col in obj_cols:
#     # isi NaN dengan modus 
#     mode_value = animals[col].mode()[0]       
#     animals[col] = animals[col].fillna(mode_value)

#     # encoding
#     # animals[col], uniques = pd.factorize(animals[col])

# %%
# plt.figure(figsize=(10,8))
# cm, labels = confusion_matrix_manual(y_val, y_pred)

# sns.heatmap(
#     cm,
#     annot=True,
#     fmt="d",
#     cmap="Blues",
#     xticklabels=labels,
#     yticklabels=labels
# )

# plt.xlabel("Ptediksi ")
# plt.ylabel("Label")
# plt.title("Confusion Matrix")
# plt.show()
